# %%
from googleplaces import GooglePlaces, types, lang 
import requests 
import json 
  
# This is the way to make api requests 
# using python requests library 
  
# send_url = 'http://freegeoip.net/json' 
# r = requests.get(send_url) 
# j = json.loads(r.text) 
# print(j) 
# lat = j['latitude'] 
# lon = j['longitude'] 
  
# Generate an API key by going to this location 
# https://cloud.google.com /maps-platform/places/?apis = 
# places in the google developers 
  
# Use your own API key for making api request calls 
API_KEY = 'AIzaSyCNp59qMzV5ZHX3HWj206LegdWQeqV0jfU'
  
# Initialising the GooglePlaces constructor 
google_places = GooglePlaces(API_KEY) 
  
# call the function nearby search with 
# the parameters as longitude, latitude, 
# radius and type of place which needs to be searched of  
# type can be HOSPITAL, CAFE, BAR, CASINO, etc 
query_result = google_places.nearby_search( 
        # lat_lng ={'lat': 46.1667, 'lng': -1.15}, 
        lat_lng ={'lat': 18.471796, 'lng': 73.867088}, 
        radius = 5000, 
        # types =[types.TYPE_HOSPITAL] or 
        # [types.TYPE_CAFE] or [type.TYPE_BAR] 
        # or [type.TYPE_CASINO]) 
        types =[types.TYPE_HOSPITAL]) 
  
# If any attributions related  
# with search results print them 
if query_result.has_attributions: 
    print (query_result.html_attributions) 
  
  
# Iterate over the search results 
for place in query_result.places: 
    # print(type(place)) 
    # place.get_details() 
    print (place.name) 
    print("Latitude", place.geo_location['lat']) 
    print("Longitude", place.geo_location['lng']) 
    print()
# Out:
# Lions Club Hospital
# Latitude 18.497485
# Longitude 73.853875
#
# Matoshri Ramabai Ambedkar Prasutigriha
# Latitude 18.5029096
# Longitude 73.8500226
#
# Dr. Gunvant Oswal G Therapy
# Latitude 18.4697896
# Longitude 73.8991693
#
# Bharati Vidyapeeth Medical Foundation's Homeopathic Hospital
# Latitude 18.4606988
# Longitude 73.85805409999999
#
# Noble Hospital
# Latitude 18.4818995
# Longitude 73.8918029
#
# Kale Hospital
# Latitude 18.4792364
# Longitude 73.86178679999999
#
# Parasnis Hospital
# Latitude 18.47468839999999
# Longitude 73.8587072
#
# Vedicure Wellness Clinic
# Latitude 18.5004708
# Longitude 73.8585507
#
# Dhanwantari
# Latitude 18.4566867
# Longitude 73.8664888
#
# Jhamwar Eye Hospital
# Latitude 18.489275
# Longitude 73.85696399999999
#
# Harsh Hospital
# Latitude 18.4811026
# Longitude 73.8662975
#
# r.k medical & general store
# Latitude 18.4651285
# Longitude 73.85508919999999
#
# krishnai medical & general stores
# Latitude 18.4704467
# Longitude 73.86506199999999
#
# Sai Hospital
# Latitude 18.4464359
# Longitude 73.8596788
#
# Poona Preventive Cardiology Center- Alternative Treatment For Heart Blockage
# Latitude 18.4858507
# Longitude 73.85418
#
# Health & Family Welfare
# Latitude 18.4768152
# Longitude 73.85550599999999
#
# Karve
# Latitude 18.48087019999999
# Longitude 73.8609962
#
# Dr Kashyap Nursing Home
# Latitude 18.470545
# Longitude 73.864271
#
# Apoorva Ayurvedic Hospital & Panchakarma Center, Pune
# Latitude 18.4846696
# Longitude 73.85198129999999
#
# Vatsalya Children's Clinic
# Latitude 18.4856078
# Longitude 73.8592883
